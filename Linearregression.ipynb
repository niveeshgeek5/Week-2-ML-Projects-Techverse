# %%
import numpy as np

# Step 1: Create Dataset
# X = Study Hours
X = np.array([1, 2, 3, 4, 5])

# Y = Marks
Y = np.array([18, 32, 40, 58, 65])

# Number of data points
n = len(X)

# Step 2: Calculate Slope (b1)

numerator = n * np.sum(X * Y) - np.sum(X) * np.sum(Y)

denominator = n * np.sum(X ** 2) - (np.sum(X)) ** 2

b1 = numerator / denominator

# Step 3: Calculate Intercept (b0)

b0 = (np.sum(Y) - b1 * np.sum(X)) / n

# Display slope and intercept

print(f"Slope (b1): {b1:.4f}")
print(f"Intercept (b0): {b0:.4f}")

# Step 4: Predict Marks

Y_pred = b0 + b1 * X

print("Predicted Marks:", Y_pred)

# Step 5: Calculate Mean Squared Error (MSE)

mse = np.mean((Y - Y_pred) ** 2)

print(f"Mean Squared Error: {mse:.4f}")
# Out:
# Slope (b1): 12.0000
# Intercept (b0): 6.6000
# Predicted Marks: [18.6 30.6 42.6 54.6 66.6]
# Mean Squared Error: 4.6400
